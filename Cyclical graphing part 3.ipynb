# %%
import numpy as np
import pandas as pd
import os
import ast

# %%
# %matplotlib inline

# %%
cwd = os.getcwd()
print(cwd)
datapath = cwd + '/../'
# Out:
# /Users/nathan/Documents/Stats/Bosch Kaggle/bosch

# %%
df = pd.read_csv(datapath + 'date_ids_df.csv', index_col = 0)

# %%
print(df.head())
# Out:
#              failures  successes    totals
# Date
# L0_S0_D7       3608.0   670254.0  673862.0
# L0_S0_D9       3608.0   670254.0  673862.0
# L0_S10_D216    1223.0   223317.0  224540.0
# L0_S10_D221    1223.0   223300.0  224523.0
# L0_S10_D226    1223.0   223317.0  224540.0

# %%
print(df.shape)
print(df.columns)
print(len(df[df.totals == 0]))
# Out:
# (1156, 3)
# Index(['failures', 'successes', 'totals'], dtype='object')
# 10

# %%
df2 = df[df.totals != 0]
print(df2.shape)
# Out:
# (1146, 3)

# %%
total_fail_rate = df2.failures / df2.totals
print(total_fail_rate.tail())
print(total_fail_rate.describe())
# Out:
# Date
# L3_S51_D4255    0.005046
# L3_S51_D4257    0.005046
# L3_S51_D4259    0.005046
# L3_S51_D4261    0.005046
# L3_S51_D4263    0.005046
# dtype: float64
# count    1146.000000
# mean        0.005779
# std         0.002116
# min         0.000000
# 25%         0.005147
# 50%         0.005466
# 75%         0.006809
# max         0.045064
# dtype: float64

# %%
total_fail_rate.to_csv('../date_failure_rate.csv')

# %%
df2.failures.plot()

# %%
fail_ratio = df2.failures / df2.totals

# %%
df2.totals.plot()

# %%
fail_ratio.plot()

# %%
low_df = df2[df2.totals < 10**5]
low_df.totals.plot()

# %%
low_fail = low_df.failures / low_df.totals
low_fail.plot()

# %%
med_df = df2[df2.totals > 2* 10**5]
med_df = med_df[med_df.totals < 3 * 10**5]
med_df.totals.plot()

# %%
med_fail = med_df.failures / med_df.totals
med_fail.plot()

# %%
high_df = df2[df2.totals > 4* 10**5]
high_df.totals.plot()

# %%
high_fail = high_df.failures / high_df.totals
high_fail.plot()

# %%
low_med_df = df2[df2.totals < 4* 10**5]

# %%
low_med_fail = low_med_df.failures / low_med_df.totals
low_med_fail.plot()

# %%
high_fail.plot.box()

# %%
low_med_fail.plot.box()

# %%
print(high_fail.mean(), low_med_fail.mean(), med_fail.mean(), low_fail.mean())
# Out:
# 0.00570696750444 0.00579231867674 0.00603623743172 0.00561753570889
